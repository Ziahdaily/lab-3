# %% [markdown]
# # Analysis of NBA dataset
#
# ### Ziah D.
#
# 10/18/19

# %% [markdown]
# ## Abstract

# %% [markdown]
# For this lab I am using pandas in order to, read the NBA dataset, and then group together the specific data for a certain team. From this I plan on analyzing the quartile ranges, along with the mean, max, and minimum.

# %% [markdown]
# ## Dataset Preperation

# %% [markdown]
# I got this dataset from Ms. Sconyers. The dataset has a total of 458 rows and 9 columns, measuring data taken from various nba teams.
#
# I am writing the code below in order to open the file, close th file and then read the data. This important because it allows us to then jump right in to using the data to then analyze it.

# %%
# Import all the modules I want to use in this homework, so they are visible to my notebook.Makes pandas accesible and shortens it to pd.
import pandas as pd

# %%
#creating the dataframe
my_df = pd.read_csv("nba.csv")

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# Now that I have all of the information that I need I am using the following pieces of code in order to look at what the data looks like. The first line of code that I asked for calls the first five rows of infomation. Afterwards, in another line of code, I ask for the last three lines of information. Having both the first and last lines allow me to see where the code starts and what the last rows look like/how many rows there are in the dataset.

# %%
my_df.head(5)
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1    Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
my_df.tail(3)
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 454     Raul Neto  Utah Jazz      25       PG   24   1-Jun     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26   3-Jul     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26  Jul-00     231  Kansas
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %% [markdown]
# After reading the first and last  lines of the data, I then move on to using our best friend info. Info allows me, as a coder, to look at what types of data there are in the dataset, and if there is any missing data.

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null int64
# Position    457 non-null object
# Age         457 non-null int64
# Height      457 non-null object
# Weight      457 non-null int64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.2+ KB

# %% [markdown]
# After using info, our best frined, we move on to our second best friend, descibe. Describe shows a lot of the ranges in the data. This is imortant becuase in previous labs we had to calculate each of these numbers individaully.

# %%
my_df.describe()
# Out:
# /Users/ziahgraceolivadaily/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000           NaN
# 50%     13.000000   26.000000  220.000000           NaN
# 75%     25.000000   30.000000  240.000000           NaN
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# The code below is key. Groupby allows us to single out the data that you want and then organizes that data.

# %%
#applying groupby() function to 
#group the data on team value
# the groupby is group all the teams...
gk = my_df.groupby('Team')

#Lets print the first entries
#in all the groups formed
gk.first()
# Out:
#                                          Name  Number Position  Age  Height  \
# Team
# Atlanta Hawks                   Kent Bazemore      24       SF   26   5-Jun
# Boston Celtics                  Avery Bradley       0       PG   25   2-Jun
# Brooklyn Nets                Bojan Bogdanovic      44       SG   27   8-Jun
# Charlotte Hornets               Nicolas Batum       5       SG   27   8-Jun
# Chicago Bulls                Cameron Bairstow      41       PF   25   9-Jun
# Cleveland Cavaliers       Matthew Dellavedova       8       PG   25   4-Jun
# Dallas Mavericks              Justin Anderson       1       SG   22   6-Jun
# Denver Nuggets                 Darrell Arthur       0       PF   28   9-Jun
# Detroit Pistons                  Joel Anthony      50        C   33   9-Jun
# Golden State Warriors         Leandro Barbosa      19       SG   33   3-Jun
# Houston Rockets                  Trevor Ariza       1       SF   30   8-Jun
# ...

# %% [markdown]
# After grouping all the different team names, I then want to group all the inforation for one team. I chose to group all the information for Miami Heat.

# %%
#finding the values contained in the "portland Miami Heat" group
gk.get_group('Miami Heat')
# Out:
#      Age                College  Height               Name  Number Position  \
# 339   32           Georgia Tech  11-Jun         Chris Bosh       1       PF
# 340   31                   Duke   9-Jun          Luol Deng       9       SF
# 341   30                    NaN   3-Jun       Goran Dragic       7       PG
# 342   30                    NaN   7-Jun       Gerald Green      14       SF
# 343   36                Florida   8-Jun      Udonis Haslem      40       PF
# 344   34               Arkansas   7-Jun        Joe Johnson       2       SF
# 345   24           Fresno State   4-Jun      Tyler Johnson       8       SG
# 346   29                   Duke  10-Jun     Josh McRoberts       4       PF
# 347   22              Tennessee   6-Jun    Josh Richardson       0       SG
# 348   33                    NaN  10-Jun  Amar'e Stoudemire       5       PF
# 349   34              Marquette   4-Jun        Dwyane Wade       3       SG
# ...

# %% [markdown]
# After grabbing all of that data, I want to use describe again, but specifaclly for the team Miami Heat.

# %%
gk.get_group('Miami Heat').describe()
# Out:
# /Users/ziahgraceolivadaily/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#              Age     Number        Salary     Weight
# count  15.000000  15.000000  1.300000e+01   15.00000
# mean   28.933333  10.466667  6.347359e+06  218.40000
# std     4.861902  10.377632  7.848628e+06   26.48126
# min    20.000000   0.000000  2.618940e+05  165.00000
# 25%    25.000000   3.500000           NaN  202.50000
# 50%    30.000000   8.000000           NaN  220.00000
# 75%    32.500000  13.000000           NaN  237.50000
# max    36.000000  40.000000  2.219273e+07  265.00000

# %% [markdown]
# Simlar to the code above I want to grab our best frined info, for the Miami Heat team.

# %%
gk.get_group('Miami Heat').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 339 to 353
# Data columns (total 8 columns):
# Age         15 non-null int64
# College     11 non-null object
# Height      15 non-null object
# Name        15 non-null object
# Number      15 non-null int64
# Position    15 non-null object
# Salary      13 non-null float64
# Weight      15 non-null int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# ## Data analysis and conclusion

# %% [markdown]
# ### Conclusion
#
# By using the pandas function and then the groupby function I was able to get some interesting information on the Miami heat team. On the Team, the maximum age for the team is 36 years old. This leads me to believe that in your late 30s you are passed your professional basketbll days. Also, learning the maximum makes me wonder what the minimum age is. Looking back to the decribe function I can see that the minimum age for the miami heat is 20 years old. The mean age for the team is around 28 years old.
#
# In additon to looking at the minimum, maximum, and mean age, I was able to look at the minimum, maximum, and mean salary for the Miami Heats. The minimum salary is $261,894.The maximum salary is $22,192,730. Lastly,the Mean salary is $6,347,359. This raises some questions (shown down below) and leads me to believe that their is a wide range of salaries in this baketball team, some making as little as two hundred and sixty one dollars, and some making as much as twenty two million.
#
#
# ### Questions Raised
#
# What is/was the oldest professional basketball player? What is/was the youngest?
#
# What is/was the highest salary for a professional basketball player? What is/was the lowest?
#
# What leads one basketball player to making more money than another?

# %% [markdown]
# ## Aknowledgements

# %% [markdown]
# Thank you to Navya, June, and Ms. Sconyers for the helping in lab 3.
